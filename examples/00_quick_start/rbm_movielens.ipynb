# %% [markdown]
# <i>Copyright (c) Microsoft Corporation. All rights reserved.</i>
#
# <i>Licensed under the MIT License.</i>

# %% [markdown]
# # Movie recommender with multinomial RBM (Tensorflow, GPU)
#
# A Restricted Boltzmann Machine (RBM) is a generative neural network model typically used to perform unsupervised learning. The main task of an RBM is to learn the joint probability distribution $P(v,h)$, where $v$ are the visible units and $h$ the hidden ones. The hidden units represent latent variables while the visible units are clamped on the input data. Once the joint distribution is learnt, new examples are generated by sampling from it.
#
# In this notebook, we provide an example of how to utilize the RBM to perform user/item recommendations. In particular, we use as a case study the [movielens dataset](https://movielens.org), comprising user's ranking of movies on a scale of 1 to 5.
#
# This notebook provides a quick start, showing the basic steps needed to use and evaluate the algorithm. A detailed discussion of the RBM model together with a deeper analysis of the recommendation task is provided in the [RBM Deep Dive section](../02_model/rbm_deep_dive.ipynb). The RBM implementation presented here is based on the article by Ruslan Salakhutdinov, Andriy Mnih and Geoffrey Hinton [Restricted Boltzmann Machines for Collaborative Filtering](https://www.cs.toronto.edu/~rsalakhu/papers/rbmcf.pdf) with the exception that here we use multinomial units instead of the one-hot encoded used in the paper.
#
# ### Advantages of RBM:
#
# The model generates ratings for a user/movie pair using a collaborative filtering based approach. While matrix factorization methods learn how to reproduce an instance of the user/item affinity matrix, the RBM learns the underlying probability distribution. This has several advantages:
#
# - Generalizability : the model generalize well to new examples.
# - Stability in time: if the recommendation task is time-stationary, the model does not need to be trained often to accomodate new ratings/users.
# - The tensorflow implementation presented here allows fast training on GPU

# %% [markdown]
# ## 0 Global Settings and Import

# %%
# set the environment path to find Recommenders
import sys

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scrapbook as sb
import tensorflow as tf
tf.get_logger().setLevel('ERROR') # only show error messages

from recommenders.models.rbm.rbm import RBM
from recommenders.datasets.python_splitters import numpy_stratified_split
from recommenders.datasets.sparse import AffinityMatrix


from recommenders.datasets import movielens
from recommenders.evaluation.python_evaluation import map_at_k, ndcg_at_k, precision_at_k, recall_at_k

#For interactive mode only
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

print("System version: {}".format(sys.version))
print("Pandas version: {}".format(pd.__version__))
print("Tensorflow version: {}".format(tf.__version__))
# Out:
# 2021-11-23 00:34:43.543569: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/intel/compilers_and_libraries_2018.1.163/linux/tbb/lib/intel64_lin/gcc4.7:/opt/intel/compilers_and_libraries_2018.1.163/linux/compiler/lib/intel64_lin:/opt/intel/compilers_and_libraries_2018.1.163/linux/mkl/lib/intel64_lin::/usr/local/cuda/lib64:/usr/local/cuda/extras/CUPTI/lib64/
# 2021-11-23 00:34:43.543732: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/intel/compilers_and_libraries_2018.1.163/linux/tbb/lib/intel64_lin/gcc4.7:/opt/intel/compilers_and_libraries_2018.1.163/linux/compiler/lib/intel64_lin:/opt/intel/compilers_and_libraries_2018.1.163/linux/mkl/lib/intel64_lin::/usr/local/cuda/lib64:/usr/local/cuda/extras/CUPTI/lib64/
# 2021-11-23 00:34:43.543749: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# System version: 3.7.11 (default, Jul 27 2021, 14:32:16)
# [GCC 7.5.0]
# Pandas version: 1.3.4
# Tensorflow version: 2.1.0

# %% [markdown]
# # 1 Load Data
#
# Here we select the size of the movielens dataset. In this example we consider the 100k ratings datasets, provided by  943 users on 1682 movies. The data are imported in a pandas dataframe including the user ID, the item ID, the ratings and a timestamp denoting when a particular user rated a particular item.

# %%
# Select MovieLens data size: 100k, 1m, 10m, or 20m
MOVIELENS_DATA_SIZE = '10m'

# %%
data = movielens.load_pandas_df(
    size=MOVIELENS_DATA_SIZE,
    header=['userID','movieID','rating','timestamp']
)

# Convert to 32-bit in order to reduce memory consumption 
data.loc[:, 'rating'] = data['rating'].astype(np.int32) 

data.head()
# Out:
# 100%|██████████| 64.0k/64.0k [00:01<00:00, 34.9kKB/s]
# Ratings should be greater than 0
#    userID  movieID  rating  timestamp
# 0       1      122       5  838985046
# 1       1      185       5  838983525
# 2       1      231       5  838983392
# 3       1      292       5  838983421
# 4       1      316       5  838983392

# %% [markdown]
# ### 1.2 Split the data using the stratified splitter
#
# As a second step we generate the user/item affiity matrix and then split the data into train and test set. If you are familiar with training supervised learning model, here you will notice the first difference. In the former case, we cut off a certain proportion of training examples from dataset (e.g. images), here corresponding to users (or items), ending up with two matrices (train and test) having different row dimensions. Here we need to mantain the same matrix size for the train and test set, but the two will contain different amounts of ratings, see the [deep dive notebook](../02_model/rbm_deep_dive.ipynb) for more details. The affinity matrix reads

# %%
#to use standard names across the analysis 
header = {
        "col_user": "userID",
        "col_item": "movieID",
        "col_rating": "rating",
    }

#instantiate the sparse matrix generation  
am = AffinityMatrix(df = data, **header)

#obtain the sparse matrix 
X, _, _ = am.gen_affinity_matrix()
# Out:
# debug __init__
# ratings value counts
# 4    3755614
# 3    2726854
# 5    2129834
# 2     908584
# 1     479168
# Name: rating, dtype: int64

# %% [markdown]
# The method also returns informations on the sparsness of the dataset and the size of the user/affinity matrix. The former is given by the ratio between the unrated elements and the total number of matrix elements. This is what makes a recommendation task hard: we try to predict 93% of the missing data with only 7% of information!
#
# We split the matrix using the default ration of 0.75, i.e. 75% of the ratings will constitute the train set.

# %%
Xtr, Xtst = numpy_stratified_split(X)

# %% [markdown]
# The splitter returns:
#
# - Xtr: a matrix containing the train set ratings
# - Xtst: a matrix containing the test elements
#
# Note that the train/test matrices have exactly the same dimension, but different entries as it can be explicitly verified:

# %%
print('train matrix size', Xtr.shape)
print('test matrix size', Xtst.shape)
# Out:
# train matrix size (69878, 10677)
# test matrix size (69878, 10677)

# %% [markdown]
# ## 2 Train the RBM model
#
# The model has been implemented as a Tensorflow (TF) class. TF does not support probabilistic models natively, so the implementation of the algorithm has a different structure than the one you may be used to see in popular supervised models. The class has been implemented in such a way that the TF session is hidden inside the `fit()` method and no explicit call is needed. The algorithm operates in three different steps:
#
# - Model initialization: This is where we tell TF how to build the computational graph. The main parameters to specify are the number of hidden units, the number of training epochs and the minibatch size. Other parameters can be optionally tweaked for experimentation and to achieve better performance, as explained in the [RBM Deep Dive section](../02_model/rbm_deep_dive.ipynb).
#
# - Model fit: This is where we train the model on the data. The method takes two arguments: the training and test set matrices. Note that the model is trained **only** on the training set, the test set is used to display the generalization accuracy of the trained model, useful to have an idea of how to fix the hyper parameters.
#
# - Model prediction: This is where we generate ratings for the unseen items. Once the model has been trained and we are satisfied with its overall accuracy, we sample new ratings from the learned distribution. In particular, we extract the top_k (e.g. 10) most relevant recommendations according to some predefined score. The prediction is then returned in a dataframe format ready to be analysed and deployed.

# %%
#First we initialize the model class
model = RBM(hidden_units= 600, training_epoch = 30, minibatch_size= 60, keep_prob=0.9,with_metrics =True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_130481/1898755475.py in <module>
#       1 #First we initialize the model class
# ----> 2 model = RBM(hidden_units= 600, training_epoch = 30, minibatch_size= 60, keep_prob=0.9,with_metrics =True)
#
# ~/notebooks/recommenders/recommenders/models/rbm/rbm.py in __init__(self, hidden_units, keep_prob, init_stdv, learning_rate, minibatch_size, training_epoch, display_epoch, sampling_protocol, debug, with_metrics, seed)
#     105         self.seed = seed
#     106         np.random.seed(self.seed)
# --> 107         tf.set_random_seed(self.seed)
#     108
#     109     def time(self):
#
# AttributeError: module 'tensorflow' has no attribute 'set_random_seed'

# %% [markdown]
# Note that the first time the fit method is called it may take longer to return the result. This is due to the fact that TF needs to initialized the GPU session. You will notice that this is not the case when training the algorithm the second or more times.

# %%
#Model Fit
train_time= model.fit(Xtr, Xtst)
# Out:
# 2021-11-22 23:45:43.233664: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-11-22 23:45:43.239999: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2596990000 Hz
# 2021-11-22 23:45:43.240297: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x558a3eaed770 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-11-22 23:45:43.240320: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-11-22 23:45:43.242676: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
#
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
# 2021-11-22 23:45:43.479512: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x558a3eb752f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-11-22 23:45:43.479555: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2021-11-22 23:45:43.480426: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0001:00:00.0
# 2021-11-22 23:45:43.480690: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcudart.so.10.0'; dlerror: libcudart.so.10.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/intel/compilers_and_libraries_2018.1.163/linux/tbb/lib/intel64_lin/gcc4.7:/opt/intel/compilers_and_libraries_2018.1.163/linux/compiler/lib/intel64_lin:/opt/intel/compilers_and_libraries_2018.1.163/linux/mkl/lib/intel64_lin::/usr/local/cuda/lib64:/usr/local/cuda/extras/CUPTI/lib64/
# 2021-11-22 23:45:43.480856: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcublas.so.10.0'; dlerror: libcublas.so.10.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/intel/compilers_and_libraries_2018.1.163/linux/tbb/lib/intel64_lin/gcc4.7:/opt/intel/compilers_and_libraries_2018.1.163/linux/compiler/lib/intel64_lin:/opt/intel/compilers_and_libraries_2018.1.163/linux/mkl/lib/intel64_lin::/usr/local/cuda/lib64:/usr/local/cuda/extras/CUPTI/lib64/
# 2021-11-22 23:45:43.481011: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcufft.so.10.0'; dlerror: libcufft.so.10.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/intel/compilers_and_libraries_2018.1.163/linux/tbb/lib/intel64_lin/gcc4.7:/opt/intel/compilers_and_libraries_2018.1.163/linux/compiler/lib/intel64_lin:/opt/intel/compilers_and_libraries_2018.1.163/linux/mkl/lib/intel64_lin::/usr/local/cuda/lib64:/usr/local/cuda/extras/CUPTI/lib64/
# 2021-11-22 23:45:43.481164: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcurand.so.10.0'; dlerror: libcurand.so.10.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/intel/compilers_and_libraries_2018.1.163/linux/tbb/lib/intel64_lin/gcc4.7:/opt/intel/compilers_and_libraries_2018.1.163/linux/compiler/lib/intel64_lin:/opt/intel/compilers_and_libraries_2018.1.163/linux/mkl/lib/intel64_lin::/usr/local/cuda/lib64:/usr/local/cuda/extras/CUPTI/lib64/
# 2021-11-22 23:45:43.481320: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcusolver.so.10.0'; dlerror: libcusolver.so.10.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/intel/compilers_and_libraries_2018.1.163/linux/tbb/lib/intel64_lin/gcc4.7:/opt/intel/compilers_and_libraries_2018.1.163/linux/compiler/lib/intel64_lin:/opt/intel/compilers_and_libraries_2018.1.163/linux/mkl/lib/intel64_lin::/usr/local/cuda/lib64:/usr/local/cuda/extras/CUPTI/lib64/
# 2021-11-22 23:45:43.481469: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcusparse.so.10.0'; dlerror: libcusparse.so.10.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/intel/compilers_and_libraries_2018.1.163/linux/tbb/lib/intel64_lin/gcc4.7:/opt/intel/compilers_and_libraries_2018.1.163/linux/compiler/lib/intel64_lin:/opt/intel/compilers_and_libraries_2018.1.163/linux/mkl/lib/intel64_lin::/usr/local/cuda/lib64:/usr/local/cuda/extras/CUPTI/lib64/
# 2021-11-22 23:45:43.485061: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-11-22 23:45:43.485104: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1641] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-11-22 23:45:43.485127: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-11-22 23:45:43.485138: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2021-11-22 23:45:43.485147: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2021-11-22 23:45:43.491586: I tensorflow/core/common_runtime/placer.cc:54] TensorSliceDataset: (TensorSliceDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491618: I tensorflow/core/common_runtime/placer.cc:54] seed2/Equal: (Equal): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491631: I tensorflow/core/common_runtime/placer.cc:54] seed2/Equal_1: (Equal): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491642: I tensorflow/core/common_runtime/placer.cc:54] seed2/LogicalAnd: (LogicalAnd): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491654: I tensorflow/core/common_runtime/placer.cc:54] seed2: (Select): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491665: I tensorflow/core/common_runtime/placer.cc:54] ShuffleDataset: (ShuffleDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491674: I tensorflow/core/common_runtime/placer.cc:54] BatchDatasetV2: (BatchDatasetV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491683: I tensorflow/core/common_runtime/placer.cc:54] RepeatDataset: (RepeatDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491708: I tensorflow/core/common_runtime/placer.cc:54] OptimizeDataset: (OptimizeDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491717: I tensorflow/core/common_runtime/placer.cc:54] ModelDataset: (ModelDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491727: I tensorflow/core/common_runtime/placer.cc:54] MakeIterator: (MakeIterator): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491738: I tensorflow/core/common_runtime/placer.cc:54] IteratorToStringHandle: (IteratorToStringHandle): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491746: I tensorflow/core/common_runtime/placer.cc:54] IteratorGetNext: (IteratorGetNext): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491755: I tensorflow/core/common_runtime/placer.cc:54] Network_parameters/weight/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491764: I tensorflow/core/common_runtime/placer.cc:54] Network_parameters/weight/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491772: I tensorflow/core/common_runtime/placer.cc:54] Network_parameters/weight/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491780: I tensorflow/core/common_runtime/placer.cc:54] Network_parameters/weight: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491787: I tensorflow/core/common_runtime/placer.cc:54] Network_parameters/weight/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491795: I tensorflow/core/common_runtime/placer.cc:54] Network_parameters/weight/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491804: I tensorflow/core/common_runtime/placer.cc:54] Network_parameters/v_bias/Initializer/zeros: (Fill): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491812: I tensorflow/core/common_runtime/placer.cc:54] Network_parameters/v_bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491820: I tensorflow/core/common_runtime/placer.cc:54] Network_parameters/v_bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491828: I tensorflow/core/common_runtime/placer.cc:54] Network_parameters/v_bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491837: I tensorflow/core/common_runtime/placer.cc:54] Network_parameters/h_bias: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491845: I tensorflow/core/common_runtime/placer.cc:54] Network_parameters/h_bias/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491853: I tensorflow/core/common_runtime/placer.cc:54] Network_parameters/h_bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491862: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_hidden_units/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491875: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_hidden_units/add: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491885: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_hidden_units/Sigmoid: (Sigmoid): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491896: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_hidden_units/dropout/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491906: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_hidden_units/dropout/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491929: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_hidden_units/dropout/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491944: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_hidden_units/dropout/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491955: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_hidden_units/dropout/random_uniform: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491965: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_hidden_units/dropout/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491976: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_hidden_units/dropout/truediv: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491986: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_hidden_units/dropout/GreaterEqual: (GreaterEqual): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.491996: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_hidden_units/dropout/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492006: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_hidden_units/dropout/Cast: (Cast): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492016: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_hidden_units/dropout/mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492026: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_hidden_units/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492037: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_hidden_units/Sign: (Sign): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492047: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_hidden_units/Relu: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492057: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_visible_units/transpose: (Transpose): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492067: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_visible_units/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492077: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_visible_units/add: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492088: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_visible_units/Mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492098: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_visible_units/Exp: (Exp): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492108: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_visible_units/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492119: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_visible_units/Exp_1: (Exp): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492131: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_visible_units/Mul_2: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492141: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_visible_units/Exp_2: (Exp): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492150: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_visible_units/Mul_3: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492161: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_visible_units/Exp_3: (Exp): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492171: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_visible_units/Mul_4: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492181: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_visible_units/Exp_4: (Exp): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492203: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_visible_units/Sum/input: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492215: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_visible_units/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492226: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_visible_units/div/x: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492237: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_visible_units/div: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492248: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_visible_units/transpose_1: (Transpose): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492259: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_visible_units/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492270: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_visible_units/Sign: (Sign): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492280: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_visible_units/Relu: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.492290: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_visible_units
(Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.494064: I tensorflow/core/common_runtime/placer.cc:54] count: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.494073: I tensorflow/core/common_runtime/placer.cc:54] optimizations: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.494081: I tensorflow/core/common_runtime/placer.cc:54] IteratorV2: (IteratorV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.494088: I tensorflow/core/common_runtime/placer.cc:54] Network_parameters/weight/Initializer/random_normal/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.494096: I tensorflow/core/common_runtime/placer.cc:54] Network_parameters/weight/Initializer/random_normal/mean: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.494104: I tensorflow/core/common_runtime/placer.cc:54] Network_parameters/weight/Initializer/random_normal/stddev: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.494111: I tensorflow/core/common_runtime/placer.cc:54] Network_parameters/v_bias/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.494119: I tensorflow/core/common_runtime/placer.cc:54] Network_parameters/v_bias/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.494127: I tensorflow/core/common_runtime/placer.cc:54] Network_parameters/h_bias/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.494137: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_hidden_units/dropout/rate: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.494148: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_hidden_units/dropout/random_uniform/min: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.494158: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_hidden_units/dropout/random_uniform/max: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.494169: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_hidden_units/dropout/sub/x: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.494179: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_hidden_units/dropout/truediv/x: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.494201: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_hidden_units/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.494213: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_visible_units/transpose/perm: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:43.494223: I tensorflow/core/common_runtime/placer.cc:54] gibbs_sampling/sample_visible_units/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# ...
# gradients/losses/MatMul_3_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/losses/MatMul_3_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/losses/MatMul_3_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/losses/MatMul_3_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/AddN_1: (AddN): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/AddN_2: (AddN): /job:localhost/replica:0/task:0/device:CPU:0
# beta1_power: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# beta1_power/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# beta1_power/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# beta2_power: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# beta2_power/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# beta2_power/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/weight/Adam/Initializer/zeros: (Fill): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/weight/Adam: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/weight/Adam/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/weight/Adam/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/weight/Adam_1/Initializer/zeros: (Fill): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/weight/Adam_1: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/weight/Adam_1/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/weight/Adam_1/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/v_bias/Adam/Initializer/zeros: (Fill): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/v_bias/Adam: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/v_bias/Adam/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/v_bias/Adam/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/v_bias/Adam_1/Initializer/zeros: (Fill): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/v_bias/Adam_1: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/v_bias/Adam_1/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/v_bias/Adam_1/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/h_bias/Adam: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/h_bias/Adam/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/h_bias/Adam/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/h_bias/Adam_1: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/h_bias/Adam_1/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/h_bias/Adam_1/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/update_Network_parameters/weight/ApplyAdam: (ApplyAdam): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/update_Network_parameters/v_bias/ApplyAdam: (ApplyAdam): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/update_Network_parameters/h_bias/ApplyAdam: (ApplyAdam): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/Assign_1: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/group_deps_1: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# Adam: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# re/NotEqual: (NotEqual): /job:localhost/replica:0/task:0/device:CPU:0
# re/Cast: (Cast): /job:localhost/replica:0/task:0/device:CPU:0
# re/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# re/SquaredDifference: (SquaredDifference): /job:localhost/replica:0/task:0/device:CPU:0
# re/zeros_like: (ZerosLike): /job:localhost/replica:0/task:0/device:CPU:0
# re/Select: (Select): /job:localhost/replica:0/task:0/device:CPU:0
# re/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# re/div: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# re/Mean: (Mean): /job:localhost/replica:0/task:0/device:CPU:0
# re/truediv: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# re/Sqrt: (Sqrt): /job:localhost/replica:0/task:0/device:CPU:0
# accuracy/NotEqual: (NotEqual): /job:localhost/replica:0/task:0/device:CPU:0
# accuracy/Cast: (Cast): /job:localhost/replica:0/task:0/device:CPU:0
# accuracy/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# accuracy/Sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# accuracy/Abs: (Abs): /job:localhost/replica:0/task:0/device:CPU:0
# accuracy/ones_like/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# accuracy/ones_like: (Fill): /job:localhost/replica:0/task:0/device:CPU:0
# accuracy/Select: (Select): /job:localhost/replica:0/task:0/device:CPU:0
# accuracy/Equal: (Equal): /job:localhost/replica:0/task:0/device:CPU:0
# accuracy/Cast_1: (Cast): /job:localhost/replica:0/task:0/device:CPU:0
# accuracy/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# accuracy/div: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# accuracy/Mean: (Mean): /job:localhost/replica:0/task:0/device:CPU:0
# init: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# Placeholder: (Placeholder): /job:localhost/replica:0/task:0/device:CPU:0
# Placeholder_1: (Placeholder): /job:localhost/replica:0/task:0/device:CPU:0
# buffer_size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# seed: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# seed2/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# seed2/Equal/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# seed2/Equal_1/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# seed2/Const_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# drop_remainder: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# count: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# optimizations: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# IteratorV2: (IteratorV2): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/weight/Initializer/random_normal/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/weight/Initializer/random_normal/mean: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/weight/Initializer/random_normal/stddev: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/v_bias/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/v_bias/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/h_bias/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gibbs_sampling/sample_hidden_units/dropout/rate: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gibbs_sampling/sample_hidden_units/dropout/random_uniform/min: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gibbs_sampling/sample_hidden_units/dropout/random_uniform/max: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gibbs_sampling/sample_hidden_units/dropout/sub/x: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gibbs_sampling/sample_hidden_units/dropout/truediv/x: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gibbs_sampling/sample_hidden_units/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gibbs_sampling/sample_visible_units/transpose/perm: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gibbs_sampling/sample_visible_units/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gibbs_sampling/sample_visible_units/Const_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gibbs_sampling/sample_visible_units/Const_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gibbs_sampling/sample_visible_units/Const_3: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gibbs_sampling/sample_visible_units/Const_4: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gibbs_sampling/sample_visible_units/Sum/reduction_indices: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gibbs_sampling/sample_visible_units/transpose_1/perm: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gibbs_sampling/sample_visible_units/Const_5: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gibbs_sampling/sample_visible_units/ArgMax/dimension: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gibbs_sampling/sample_visible_units/add_1/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gibbs_sampling/sample_visible_units/Equal/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# losses/transpose/perm: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# losses/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# losses/Const_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# losses/transpose_1/perm: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# losses/Const_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# losses/Const_3: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/Shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/grad_ys_0: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/losses/Sum_grad/Reshape/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/losses/Sum_1_grad/Reshape/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/losses/Sum_2_grad/Reshape/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/losses/Sum_3_grad/Reshape/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/beta1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/beta2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/epsilon: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/learning_rate: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/weight/Adam/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/weight/Adam/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/weight/Adam_1/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/weight/Adam_1/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/v_bias/Adam/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/v_bias/Adam/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/v_bias/Adam_1/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/v_bias/Adam_1/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/h_bias/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Network_parameters/h_bias/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# re/NotEqual/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# re/Sum/reduction_indices: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# re/Sum_1/reduction_indices: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# re/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# re/truediv/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# accuracy/NotEqual/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# accuracy/Sum/reduction_indices: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# accuracy/ones_like/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# accuracy/Equal/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# accuracy/Sum_1/reduction_indices: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# accuracy/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-11-22 23:45:44.932858: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 2984349624 exceeds 10% of system memory.
# 2021-11-22 23:45:46.146574: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 2984349624 exceeds 10% of system memory.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_121085/2301366883.py in <module>
#       1 #Model Fit
# ----> 2 train_time= model.fit(Xtr, Xtst)
#
# ~/notebooks/recommenders/recommenders/models/rbm/rbm.py in fit(self, xtr, xtst)
#     701
#     702             self.gibbs_protocol(i)  # Gibbs sampling update
# --> 703             epoch_tr_err = self.batch_training(num_minibatches)  # model train
#     704
#     705             if self.with_metrics and i % self.display == 0:
#
# ~/notebooks/recommenders/recommenders/models/rbm/rbm.py in batch_training(self, num_minibatches)
#     645             # minibatch loop
#     646             for l in range(num_minibatches):  # noqa: E741 ambiguous variable name 'l'
# --> 647                 _, batch_err = self.sess.run([self.opt, self.Rmse])
#     648                 # average msr error per minibatch
#     649                 epoch_tr_err += batch_err / num_minibatches
#
# /anaconda/envs/reco_env/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /anaconda/envs/reco_env/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# /anaconda/envs/reco_env/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /anaconda/envs/reco_env/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# /anaconda/envs/reco_env/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# /anaconda/envs/reco_env/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# During training, we can optionlly evauate the root mean squared error to have an idea of how the learning is proceeding. We would generally like to see this quantity decreasing as a function of the learning epochs. To visualise this choose `with_metrics = True` in the `RBM()` model function.
#
# Once the model has been trained, we can predict new ratings on the test set.

# %%
#number of top score elements to be recommended  
K = 10

#Model prediction on the test set Xtst. 
top_k, test_time =  model.recommend_k_items(Xtst)
# Out:
# Extracting top 10 elements
# Done recommending items, time 0.1904082

# %% [markdown]
# `top_k` returns the first K elements having the highest recommendation score. Here the recommendation score is evaluated by multiplying the predicted rating by its probability, i.e. the confidence the algorithm has about its output. So if we have two items both with predicted ratings 5, but one with probability 0.5 and the other 0.9, the latter will be considered more relevant. In order to inspect the prediction and use the evaluation metrics in this repository, we convert both top_k and Xtst to pandas dataframe format:

# %%
top_k_df = am.map_back_sparse(top_k, kind = 'prediction')
test_df = am.map_back_sparse(Xtst, kind = 'ratings')

# %%
top_k_df.head(10)
# Out:
#    userID  movieID  prediction
# 0       1        4    4.989026
# 1       1      242    4.990839
# 2       1      161    4.987231
# 3       1      170    4.992252
# 4       1      223    4.997586
# 5       1      239    4.987444
# 6       1       31    4.989766
# 7       1      269    4.990007
# 8       1      357    4.995893
# 9       1      647    4.988303

# %% [markdown]
# ## 4 Evaluation metrics
#
# Here we evaluate the performance of the algorithm using the metrics provided in the `PythonRankingEvaluation` class. Note that the following metrics take into account only the first K elements, therefore their value may be different from the one displayed from the `model.fit()` method.

# %%
def ranking_metrics(
    data_size,
    data_true,
    data_pred,
    time_train,
    time_test,
    K
):

    eval_map = map_at_k(data_true, data_pred, col_user="userID", col_item="movieID", 
                    col_rating="rating", col_prediction="prediction", 
                    relevancy_method="top_k", k= K)

    eval_ndcg = ndcg_at_k(data_true, data_pred, col_user="userID", col_item="movieID", 
                      col_rating="rating", col_prediction="prediction", 
                      relevancy_method="top_k", k= K)

    eval_precision = precision_at_k(data_true, data_pred, col_user="userID", col_item="movieID", 
                               col_rating="rating", col_prediction="prediction", 
                               relevancy_method="top_k", k= K)

    eval_recall = recall_at_k(data_true, data_pred, col_user="userID", col_item="movieID", 
                          col_rating="rating", col_prediction="prediction", 
                          relevancy_method="top_k", k= K)

    
    df_result = pd.DataFrame(
        {   "Dataset": data_size,
            "K": K,
            "MAP": eval_map,
            "nDCG@k": eval_ndcg,
            "Precision@k": eval_precision,
            "Recall@k": eval_recall,
            "Train time (s)": time_train,
            "Test time (s)": time_test
        }, 
        index=[0]
    )
    
    return df_result

# %%
eval_100k= ranking_metrics(
    data_size = "mv 100k",
    data_true =test_df,
    data_pred =top_k_df,
    time_train=train_time,
    time_test =test_time,
    K =10)

eval_100k
# Out:
#    Dataset   K      MAP    nDCG@k  Precision@k  Recall@k  Train time (s)  \
# 0  mv 100k  10  0.40663  0.818305     0.698621  0.432109        2.541901
#
#    Test time (s)
# 0       0.190408

# %%
# Record results with papermill for tests
sb.glue("map", eval_100k['MAP'][0])
sb.glue("ndcg", eval_100k['nDCG@k'][0])
sb.glue("precision", eval_100k['Precision@k'][0])
sb.glue("recall", eval_100k['Recall@k'][0])
sb.glue("train_time", train_time)
sb.glue("test_time", test_time)
